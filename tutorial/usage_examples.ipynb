# %% [markdown]
# # WELCOME!

# %% [markdown]
# Thanks for using this software! Below is a tutorial to work your through the pipeline.
#
# Thankfully it's super straight forward!

# %% [markdown]
# # Requirements
#
# ### **1) Setting up a conda enviroment**
# A conda enviroment is essentially a seperate and safe bubble to work on your code without risking changing additional settings you used for other projects.
#
# In this repository you can find an `envrioment.yml` file that can be used to help set up your enviroment to be the same as how this repository was ran on when developed.
#
# The [attached link](https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html) has additional resources related to setting up a conda enviroment.

# %% [markdown]
# #### Where do you find the `envrioment.yml` file?
#
# This is located in the `multicolormaize/` directory.
#
# Additionally, this is the path directory from where this `usage_examples.ipnb` is located: `../multicolormaize/enviroment.yml`

# %% [markdown]
# #### Code on how to create a new enviroment using `.yml`

# %% [markdown]
# `conda env create -n you_envirment_name -f environment.yml` --> create the enviroment using the enviroment file
#
# `conda activate myenv`  --> activate your enviroment

# %% [markdown]
# ---
# # Files Break Down
#
# The pupose of this pipeline is to compare model predictions for pheno typic traits of interest in maize *(silk color, anther color, and specific leaf weight)*. Here are 3 types of data that can be used as input datasets
#
# #### 1) Data types examples
# - phenotypic traits
# - field drone imagery
# - phenolic compound accumulation in leaf tissue
#
#
# The following files are python files that will be used throughou the pipeline
# #### 2) Python scripts
# - datapreprocessing.py
# - runmodels.py
# - featureselection.py
# - multicolormaize.py

# %% [markdown]
# ---
# # Pipeline Breakdown
# Please note that the order of the files is **NOT** how you use the pipeline, but is how the pipeline works as a whole from start to end. The last step is how you actually implement the software decribed to that point.
#
# 1) `datapreprocessing.py`
# This file would be the first step in the pipeline. Here you input a file location for your data of interst. In our example we will use RGB drone imagery data.
# **What does this script do:**
# - it removes duplicates
# - removes outliers
# - scales the data
# - addresses NAs in the data

# %% [markdown]
# 2) `runmodels.py`
# Here you input a cleaned data file outputted from step 1.
# **What does this script do:**
# - Undergoes the first splitting of the data into training and testing dataset
# - Takes the training dataset and does an additional splitting into a sub-training set and a validation set. A validation dataset allows us to evaluate the model without compromises our testing set. Using the validation model performances we can then identify the beset prediction model followed by top feature selection.

# %% [markdown]
# 3) `featureselections.py`
# After you generate model performances based on the validation sets, you will need to select the top perfoming model algorithm. This script takes the top performing.
# - qauntifying the most impactful features in predictions
# - generates new subset of original input data but only containing the top features. *(this helps cut down computational time)*

# %% [markdown]
# 4) `multicolormaize.py`
#
# This is the script that actually runs all the above automatically.
#
# *NOTE!!!* In this script this is where you will need to change the path to the input file. Currently the script uses the provided test set in this `./tutorial` folder/directory.

# %% [markdown]
# ---
# # Running the Pipeline
#
# ### Costomization you will need to make
#
# `multicolormaize.py`
#    1) **File Paths**: you will need to add path(s) of your files to the
#     `data_paths` variable.
#    *!! THIS DOES NOT SYSTEMATIICALLY COMBINE MANY
#      DATASETS INTO PARS OF TWO, YOU WILL NEED TO RUN THE PIPELINE
#      EVERYTIME YOU WANT TO COMBINE DIFFERENT FILE COMBINATIONS !!*
#         - `data_paths = ["../you/file/path",
#         #Add other file paths as needed]`
#
#    2) **Sample columns/column that multiple files will merge on**:
#     you will need to add the column name that is shared between both/all
#      files in order to concat together
#         - `merge_column = "GRIN"`
#
#    3) **Y_column/ What column you will be prediction**: you will need to
#     put in the column file that you will want to predict
#         - `y_column = "AntherColor"`
#
#    4) **Any columns you don't want to include**
#       - `columns_to_drop = ["SilkColor"]`

# %%
# !python ../multimodel_pipeline/multicolormaize.py
# Out:
# C:\Users\amsch\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# *****************************************************************
#
# -----------------------
# STARTING TO LOAD DATA FROM ../tutorial/widiv_2021drone_SilkandAntherColor.csv!
# -----------------------
#
# Yay, the file exists!
#
# *****************************************************************
#
# ------------------------
# STARTING DATA CLEANING!
# -------------------------
#
# --- Removing duplicate rows ---
#
# Shape of df before dups rows meaned: (761, 836)
#
# Shape of df after dups rows meaned: (761, 836)
#
# --- Dropping unwanted columns ---
#
# --- Converted Y_col to numeric classes ---
#  1.0    474
# 2.0    287
# Name: AntherColor, dtype: int64
#
# --- Dropping/imputing columns with too many NAs ---
#
# Total number of columns dropped: 0
#
# --- Starting Scaling Data... ---
#
# --- Completed Scaling! ---
#
# --- Snapshot of final imputed data ---
#             AntherColor  0603_NC_red_SUM  ...  0603_NC_red_MEDIAN  0603_NC_red_STDEV
# GRIN                                     ...
# Ames10254          1.0        -0.307057  ...           -0.379966           0.339749
# Ames10256          1.0        -0.535059  ...            0.174500          -0.021408
# Ames12726          1.0        -0.455299  ...            0.174500           0.733877
# Ames12731          2.0         1.190280  ...            1.006198           0.291194
# Ames12732          1.0        -1.807241  ...           -0.934431          -1.214349
#
# [5 rows x 5 columns]
#
# Output file saved as: widiv_2021drone_SilkandAntherColor_predicting_AntherColor_preprocessed.txt
#
# -----------------------
# DATA CLEANING COMPLETE!
# -----------------------
#
# *****************************************************************
#
# --------------------------------------------
# SPLITTING DATA INTO TRAINING AND TEST SETS
# --------------------------------------------
# X_train shape: (608, 834)
# y_train shape: (608,)
# X_test shape: (153, 834)
# y_test shape: (153,)
#
# ----------------------------
# DATA SUCCESSFULLY SPLIT!
# ----------------------------
#
# *****************************************************************
#
# -------------------------------------------------------------
# STARTING TO RUN MODELS AND GENERATE FEATURE IMPORTANCE SCORES!
# -------------------------------------------------------------
# Class mapping to 0 and 1:
# Class 1.0 is mapped to 0.
# Class 2.0 is mapped to 1.
#
# --- Generating results ---
#
# The following models will be run on the dataset:
#
# Logistic Regression
# Decision Tree
# Random Forest
# K-Nearest Neighbors
# Support Vector Machine
# Gaussian Naive Bayes
# Multilayer Perceptron
# Linear Discriminant Analysis
# Gradient Boosting Classifier
# AdaBoost Classifier
# Extra Trees Classifier
# Quadratic Discriminant Analysis
# XGBoost Classifier
# LightGBM Classifier
#
# --- Generating feature importance scores for each model ---
#
# -----------------------------------------------------------------
# COMPLETED MODEL GENERATION WITH RESULTS AND FEATURE IMPORTANCE!
# -----------------------------------------------------------------
#
# Feature Importances:
#
# Model: Logistic Regression
# Feature: 0603_NC_red_SUM, Importance: 0.2984288611004158
# Feature: 0603_NC_red_MEAN, Importance: 0.08984522047671227
# Feature: 0603_NC_red_MEDIAN, Importance: 0.11288829375061885
# Feature: 0603_NC_red_STDEV, Importance: 0.14777189474044466
# Feature: 0603_NC_red_MIN, Importance: 0.36108281470669157
# Feature: 0603_NC_red_5, Importance: 0.22066023562973125
# Feature: 0603_NC_green_SUM, Importance: 0.2531929472433765
# Feature: 0603_NC_green_MEAN, Importance: 0.12243710314726204
# Feature: 0603_NC_green_MEDIAN, Importance: 0.399300729649354
# Feature: 0603_NC_green_STDEV, Importance: 0.13742524191473818
# Feature: 0603_NC_green_MIN, Importance: 0.592005122150962
# Feature: 0603_NC_green_5, Importance: 0.20420305912933498
# Feature: 0603_NC_blue_SUM, Importance: 0.25462945192855924
# Feature: 0603_NC_blue_MEAN, Importance: 0.14883406518019865
# Feature: 0603_NC_blue_MEDIAN, Importance: 0.4977630998842071
# Feature: 0603_NC_blue_STDEV, Importance: 0.06291491466947922
# Feature: 0603_NC_blue_MIN, Importance: 0.569374452059307
# Feature: 0603_NC_blue_5, Importance: 0.24690622688883804
# Feature: 0603_MS_blue_SUM, Importance: 0.030055025040948653
# Feature: 0603_MS_blue_MEAN, Importance: 0.022335247634996933
# Feature: 0603_MS_blue_MEDIAN, Importance: 0.011517225848843213
# Feature: 0603_MS_blue_STDEV, Importance: 0.19304555805469184
# Feature: 0603_MS_blue_MIN, Importance: 0.5701229801228037
# Feature: 0603_MS_blue_5, Importance: 0.6285592371108415
# Feature: 0603_MS_green_SUM, Importance: 0.015807589560508723
# Feature: 0603_MS_green_MEAN, Importance: 0.04102063500931309
# Feature: 0603_MS_green_MEDIAN, Importance: 0.04076176646345515
# Feature: 0603_MS_green_STDEV, Importance: 0.07914210085554456
# Feature: 0603_MS_green_MIN, Importance: 0.19973387400259385
# Feature: 0603_MS_green_5, Importance: 1.1639182133421855
# Feature: 0603_MS_nir_SUM, Importance: 0.20835588525147125
# Feature: 0603_MS_nir_MEAN, Importance: 0.2691765097901471
# Feature: 0603_MS_nir_MEDIAN, Importance: 0.21946805243466236
# Feature: 0603_MS_nir_STDEV, Importance: 0.38088033362812784
# Feature: 0603_MS_nir_MIN, Importance: 0.427121672652964
# Feature: 0603_MS_nir_5, Importance: 0.10258683548757366
# Feature: 0603_MS_red_SUM, Importance: 0.4942806617703556
# Feature: 0603_MS_red_MEAN, Importance: 0.5206325631519774
# Feature: 0603_MS_red_MEDIAN, Importance: 0.4884937716894845
# Feature: 0603_MS_red_STDEV, Importance: 0.4569666456626971
# Feature: 0603_MS_red_MIN, Importance: 0.006734805909308856
# Feature: 0603_MS_red_5, Importance: 0.36967318384664394
# Feature: 0603_MS_redge_SUM, Importance: 0.09555767827185503
# Feature: 0603_MS_redge_MEAN, Importance: 0.0769882125398724
# Feature: 0603_MS_redge_MEDIAN, Importance: 0.14313123536516437
# Feature: 0603_MS_redge_STDEV, Importance: 0.11534189213325731
# Feature: 0603_MS_redge_MIN, Importance: 0.6140378531895664
# Feature: 0603_MS_redge_5, Importance: 0.0919298666965692
# Feature: 0606_NC_red_SUM, Importance: 0.24142449270606503
# Feature: 0606_NC_red_MEAN, Importance: 0.3567486523913218
# Feature: 0606_NC_red_MEDIAN, Importance: 0.19385040216946747
# Feature: 0606_NC_red_STDEV, Importance: 0.2593464733881773
# Feature: 0606_NC_red_MIN, Importance: 0.16647451065776234
# Feature: 0606_NC_red_5, Importance: 0.030059489225919795
# Feature: 0606_NC_green_SUM, Importance: 0.30149686980306284
# Feature: 0606_NC_green_MEAN, Importance: 0.2609628973428716
# Feature: 0606_NC_green_MEDIAN, Importance: 0.24636281793612536
# Feature: 0606_NC_green_STDEV, Importance: 0.2492525757420967
# Feature: 0606_NC_green_MIN, Importance: 0.06310144972731949
# Feature: 0606_NC_green_5, Importance: 0.3777297628850905
# Feature: 0606_NC_blue_SUM, Importance: 0.16785321829604616
# Feature: 0606_NC_blue_MEAN, Importance: 0.100150716400195
# Feature: 0606_NC_blue_MEDIAN, Importance: 0.1370664665430296
# Feature: 0606_NC_blue_STDEV, Importance: 0.04010180335429068
# Feature: 0606_NC_blue_MIN, Importance: 0.1917464493506421
# Feature: 0606_NC_blue_5, Importance: 0.19336021135937378
# Feature: 0606_MS_blue_SUM, Importance: 0.12674396725617837
# Feature: 0606_MS_blue_MEAN, Importance: 0.3360003197223198
# Feature: 0606_MS_blue_MEDIAN, Importance: 0.24296626492352433
# Feature: 0606_MS_blue_STDEV, Importance: 0.29298962088456154
# Feature: 0606_MS_blue_MIN, Importance: 0.2512872536402755
# Feature: 0606_MS_blue_5, Importance: 0.04347504744905725
# Feature: 0606_MS_green_SUM, Importance: 0.1059721800523556
# Feature: 0606_MS_green_MEAN, Importance: 0.09634818631002522
# Feature: 0606_MS_green_MEDIAN, Importance: 0.07764807593923036
# Feature: 0606_MS_green_STDEV, Importance: 0.24302531690514115
# Feature: 0606_MS_green_MIN, Importance: 0.048183571294021815
# Feature: 0606_MS_green_5, Importance: 0.24478310036124634
# Feature: 0606_MS_nir_SUM, Importance: 0.23822825005595602
# Feature: 0606_MS_nir_MEAN, Importance: 0.056838795758633744
# Feature: 0606_MS_nir_MEDIAN, Importance: 0.09309432647151732
# Feature: 0606_MS_nir_STDEV, Importance: 0.12834446985302872
# Feature: 0606_MS_nir_MIN, Importance: 0.3539482121879984
# Feature: 0606_MS_nir_5, Importance: 1.176907411994543
# Feature: 0606_MS_red_SUM, Importance: 0.05690193520113725
# Feature: 0606_MS_red_MEAN, Importance: 0.1738278895721987
# Feature: 0606_MS_red_MEDIAN, Importance: 0.08710644298184181
# Feature: 0606_MS_red_STDEV, Importance: 0.24075588652255292
# Feature: 0606_MS_red_MIN, Importance: 0.10071453862429107
# Feature: 0606_MS_red_5, Importance: 0.01637496327721393
# Feature: 0606_MS_redge_SUM, Importance: 0.24157466861786964
# Feature: 0606_MS_redge_MEAN, Importance: 0.03513986278562802
# Feature: 0606_MS_redge_MEDIAN, Importance: 0.1320505579206737
# Feature: 0606_MS_redge_STDEV, Importance: 0.2658875960566907
# Feature: 0606_MS_redge_MIN, Importance: 0.8022543483839116
# Feature: 0606_MS_redge_5, Importance: 0.33302094072028166
# Feature: 0611_NC_red_SUM, Importance: 0.12994137816965715
# Feature: 0611_NC_red_MEAN, Importance: 0.34422800751958377
# Feature: 0611_NC_red_MEDIAN, Importance: 0.10585848658756213
# Feature: 0611_NC_red_STDEV, Importance: 0.1506915822519097
# Feature: 0611_NC_red_MIN, Importance: 0.24592855266896005
# Feature: 0611_NC_red_5, Importance: 0.24091534183988328
# Feature: 0611_NC_green_SUM, Importance: 0.08702039847549345
# Feature: 0611_NC_green_MEAN, Importance: 0.08962162020354043
# Feature: 0611_NC_green_MEDIAN, Importance: 0.22621470692748608
# Feature: 0611_NC_green_STDEV, Importance: 0.08815858360551881
# Feature: 0611_NC_green_MIN, Importance: 0.07826906674021906
# Feature: 0611_NC_green_5, Importance: 0.15689910932533424
# Feature: 0611_NC_blue_SUM, Importance: 0.16052244604015165
# Feature: 0611_NC_blue_MEAN, Importance: 0.027055528151494854
# Feature: 0611_NC_blue_MEDIAN, Importance: 0.30604750492497734
# Feature: 0611_NC_blue_STDEV, Importance: 0.14022563916999
# Feature: 0611_NC_blue_MIN, Importance: 0.20425031404443827
# Feature: 0611_NC_blue_5, Importance: 0.24054857279568773
# Feature: 0611_MS_blue_SUM, Importance: 0.20132672793144563
# Feature: 0611_MS_blue_MEAN, Importance: 0.06096359200695649
# Feature: 0611_MS_blue_MEDIAN, Importance: 0.12555061821778737
# Feature: 0611_MS_blue_STDEV, Importance: 0.11281506350341174
# Feature: 0611_MS_blue_MIN, Importance: 0.14836812135276195
# Feature: 0611_MS_blue_5, Importance: 0.16361044401956934
# Feature: 0611_MS_green_SUM, Importance: 0.22203298737952268
# Feature: 0611_MS_green_MEAN, Importance: 0.3399864663515882
# Feature: 0611_MS_green_MEDIAN, Importance: 0.4018766531404595
# Feature: 0611_MS_green_STDEV, Importance: 0.523563866545583
# Feature: 0611_MS_green_MIN, Importance: 0.4314542255560512
# Feature: 0611_MS_green_5, Importance: 0.33520108934106124
# Feature: 0611_MS_nir_SUM, Importance: 0.4306261947896038
# Feature: 0611_MS_nir_MEAN, Importance: 0.42110866057618435
# Feature: 0611_MS_nir_MEDIAN, Importance: 0.2997415450245886
# Feature: 0611_MS_nir_STDEV, Importance: 0.15601186969149275
# Feature: 0611_MS_nir_MIN, Importance: 0.4679555337426714
# Feature: 0611_MS_nir_5, Importance: 0.1404509720843618
# Feature: 0611_MS_red_SUM, Importance: 0.12329959552617999
# Feature: 0611_MS_red_MEAN, Importance: 0.0375815073828135
# Feature: 0611_MS_red_MEDIAN, Importance: 0.05992479122333609
# Feature: 0611_MS_red_STDEV, Importance: 0.3110194295540254
# Feature: 0611_MS_red_MIN, Importance: 0.4650789958879829
# Feature: 0611_MS_red_5, Importance: 0.01567384374209496
# Feature: 0611_MS_redge_SUM, Importance: 0.13581663621737908
# Feature: 0611_MS_redge_MEAN, Importance: 0.06182181664949446
# Feature: 0611_MS_redge_MEDIAN, Importance: 0.02217970748214227
# Feature: 0611_MS_redge_STDEV, Importance: 0.36850860058481805
# Feature: 0611_MS_redge_MIN, Importance: 0.4241043278635875
# Feature: 0611_MS_redge_5, Importance: 0.06506537043291143
# Feature: 0719_MS_redge_SUM, Importance: 0.24348727614383658
# Feature: 0719_MS_redge_MEAN, Importance: 0.18968884012491602
# Feature: 0719_MS_redge_MEDIAN, Importance: 0.20894049423283242
# Feature: 0719_MS_redge_STDEV, Importance: 0.0050580984091080404
# Feature: 0719_MS_redge_MIN, Importance: 0.511668851104402
# Feature: 0719_MS_redge_5, Importance: 0.47219314363471143
# Feature: 0726_NC_red_SUM, Importance: 0.548241320231475
# Feature: 0726_NC_red_MEAN, Importance: 0.5471648140986777
# Feature: 0726_NC_red_MEDIAN, Importance: 0.6850965982327489
# Feature: 0726_NC_red_STDEV, Importance: 0.05695539647314215
# Feature: 0726_NC_red_MIN, Importance: 0.677391913855868
# Feature: 0726_NC_red_5, Importance: 0.30830904226174105
# Feature: 0726_NC_green_SUM, Importance: 0.42243211477159875
# Feature: 0726_NC_green_MEAN, Importance: 0.4232159485148429
# Feature: 0726_NC_green_MEDIAN, Importance: 0.4767904832691028
# Feature: 0726_NC_green_STDEV, Importance: 0.2834442220331108
# Feature: 0726_NC_green_MIN, Importance: 0.836791136247449
# Feature: 0726_NC_green_5, Importance: 0.5610764286374755
# Feature: 0726_NC_blue_SUM, Importance: 0.22012918188988573
# Feature: 0726_NC_blue_MEAN, Importance: 0.22857136567932762
# Feature: 0726_NC_blue_MEDIAN, Importance: 0.25251322032466206
# Feature: 0726_NC_blue_STDEV, Importance: 0.1764781686578897
# Feature: 0726_NC_blue_MIN, Importance: 0.5452916793422499
# Feature: 0726_NC_blue_5, Importance: 0.12585226313871764
# Feature: 0726_MS_blue_SUM, Importance: 0.3090380992607417
# Feature: 0726_MS_blue_MEAN, Importance: 0.12054609286390802
# Feature: 0726_MS_blue_MEDIAN, Importance: 0.16488646508348875
# Feature: 0726_MS_blue_STDEV, Importance: 0.11607648777046352
# Feature: 0726_MS_blue_MIN, Importance: 0.021069289338177102
# Feature: 0726_MS_blue_5, Importance: 0.11975486749605717
# Feature: 0726_MS_green_SUM, Importance: 0.35954899285712344
# Feature: 0726_MS_green_MEAN, Importance: 0.10959630003532651
# Feature: 0726_MS_green_MEDIAN, Importance: 0.3870792111241438
# Feature: 0726_MS_green_STDEV, Importance: 0.08944117890568358
# Feature: 0726_MS_green_MIN, Importance: 0.21927070968078977
# Feature: 0726_MS_green_5, Importance: 0.6674826025582313
# Feature: 0726_MS_nir_SUM, Importance: 0.09123201800513599
# Feature: 0726_MS_nir_MEAN, Importance: 0.13294406862989425
# Feature: 0726_MS_nir_MEDIAN, Importance: 0.9079748033624025
# Feature: 0726_MS_nir_STDEV, Importance: 0.5354525546832191
# Feature: 0726_MS_nir_MIN, Importance: 0.04596154164737741
# Feature: 0726_MS_nir_5, Importance: 0.13571875211060416
# Feature: 0726_MS_red_SUM, Importance: 0.1697606884133829
# Feature: 0726_MS_red_MEAN, Importance: 0.13574576485151063
# Feature: 0726_MS_red_MEDIAN, Importance: 0.11582604628345028
# Feature: 0726_MS_red_STDEV, Importance: 0.40509166102267063
# Feature: 0726_MS_red_MIN, Importance: 0.5719907127779106
# Feature: 0726_MS_red_5, Importance: 0.3884612742610229
# Feature: 0726_MS_redge_SUM, Importance: 0.20737925925315231
# Feature: 0726_MS_redge_MEAN, Importance: 0.047373092848877064
# Feature: 0726_MS_redge_MEDIAN, Importance: 0.010737794143303045
# Feature: 0726_MS_redge_STDEV, Importance: 0.36497383550792817
# Feature: 0726_MS_redge_MIN, Importance: 0.755951103050228
# Feature: 0726_MS_redge_5, Importance: 0.43761973479075733
# Feature: 0802_NC_red_SUM, Importance: 0.19582961184558492
# Feature: 0802_NC_red_MEAN, Importance: 0.07343179048407769
# Feature: 0802_NC_red_MEDIAN, Importance: 0.15257336959791826
# Feature: 0802_NC_red_STDEV, Importance: 0.8566089404967936
# Feature: 0802_NC_red_MIN, Importance: 0.28482245045952587
# Feature: 0802_NC_red_5, Importance: 0.15490624153755594
# Feature: 0802_NC_green_SUM, Importance: 0.5103040268967816
# Feature: 0802_NC_green_MEAN, Importance: 0.376133738728376
# Feature: 0802_NC_green_MEDIAN, Importance: 0.5684057508406554
# Feature: 0802_NC_green_STDEV, Importance: 0.6515757279824262
# Feature: 0802_NC_green_MIN, Importance: 0.09696518873954851
# Feature: 0802_NC_green_5, Importance: 0.4316074822918261
# Feature: 0802_NC_blue_SUM, Importance: 0.040808883135614794
# Feature: 0802_NC_blue_MEAN, Importance: 0.12259821019594902
# Feature: 0802_NC_blue_MEDIAN, Importance: 0.06264123739487763
# Feature: 0802_NC_blue_STDEV, Importance: 0.43062733903362127
# Feature: 0802_NC_blue_MIN, Importance: 0.5348466228207357
# Feature: 0802_NC_blue_5, Importance: 1.5156652356005638
# Feature: 0802_MS_blue_SUM, Importance: 0.22073821975428431
# Feature: 0802_MS_blue_MEAN, Importance: 0.0007802032295245559
# Feature: 0802_MS_blue_MEDIAN, Importance: 0.020124153650388606
# Feature: 0802_MS_blue_STDEV, Importance: 0.2238279349716702
# Feature: 0802_MS_blue_MIN, Importance: 0.39529250338954186
# Feature: 0802_MS_blue_5, Importance: 1.1820581648103679
# Feature: 0802_MS_green_SUM, Importance: 0.6634966021752534
# Feature: 0802_MS_green_MEAN, Importance: 0.33500484464153313
# Feature: 0802_MS_green_MEDIAN, Importance: 0.27713658456581736
# Feature: 0802_MS_green_STDEV, Importance: 0.08120128858243138
# Feature: 0802_MS_green_MIN, Importance: 0.7061762984109833
# Feature: 0802_MS_green_5, Importance: 0.13717181763788464
# Feature: 0802_MS_nir_SUM, Importance: 0.3671638521886464
# Feature: 0802_MS_nir_MEAN, Importance: 0.3001853186684465
# Feature: 0802_MS_nir_MEDIAN, Importance: 0.7720964031186721
# Feature: 0802_MS_nir_STDEV, Importance: 0.17344934059470843
# Feature: 0802_MS_nir_MIN, Importance: 0.053382659562149444
# Feature: 0802_MS_nir_5, Importance: 0.36229101822342186
# Feature: 0802_MS_red_SUM, Importance: 0.20663654124464434
# Feature: 0802_MS_red_MEAN, Importance: 0.23887634187447637
# Feature: 0802_MS_red_MEDIAN, Importance: 0.2996641980833085
# Feature: 0802_MS_red_STDEV, Importance: 0.11040888518763539
# Feature: 0802_MS_red_MIN, Importance: 0.400048486852769
# Feature: 0802_MS_red_5, Importance: 0.3187849741691425
# Feature: 0802_MS_redge_SUM, Importance: 0.06629165728485192
# Feature: 0802_MS_redge_MEAN, Importance: 0.09496205755000516
# Feature: 0802_MS_redge_MEDIAN, Importance: 0.21158583853953816
# Feature: 0802_MS_redge_STDEV, Importance: 0.1252151697600498
# Feature: 0802_MS_redge_MIN, Importance: 0.8978503183601679
# Feature: 0802_MS_redge_5, Importance: 0.5401138017761369
# Feature: 0810_NC_red_SUM, Importance: 0.12460485717893956
# Feature: 0810_NC_red_MEAN, Importance: 0.06505258443200443
# Feature: 0810_NC_red_MEDIAN, Importance: 0.1521758096561722
# Feature: 0810_NC_red_STDEV, Importance: 0.144204526277179
# Feature: 0810_NC_red_MIN, Importance: 0.6052913138181366
# Feature: 0810_NC_red_5, Importance: 0.08175092709133698
# Feature: 0810_NC_green_SUM, Importance: 0.5474848184883966
# Feature: 0810_NC_green_MEAN, Importance: 0.6522264472615473
# Feature: 0810_NC_green_MEDIAN, Importance: 0.7077317891569964
# Feature: 0810_NC_green_STDEV, Importance: 0.2922345097507194
# Feature: 0810_NC_green_MIN, Importance: 0.2802585728271067
# Feature: 0810_NC_green_5, Importance: 0.6046106962376668
# Feature: 0810_NC_blue_SUM, Importance: 0.04587718824128239
# Feature: 0810_NC_blue_MEAN, Importance: 0.07620197246424151
# Feature: 0810_NC_blue_MEDIAN, Importance: 0.006442647608949309
# Feature: 0810_NC_blue_STDEV, Importance: 0.25400715302261423
# Feature: 0810_NC_blue_MIN, Importance: 0.6688084871102569
# Feature: 0810_NC_blue_5, Importance: 0.32631973844265955
# Feature: 0810_MS_blue_SUM, Importance: 0.05329936594714783
# Feature: 0810_MS_blue_MEAN, Importance: 0.09221832768511075
# Feature: 0810_MS_blue_MEDIAN, Importance: 0.06497605066244064
# Feature: 0810_MS_blue_STDEV, Importance: 0.1541310524722161
# Feature: 0810_MS_blue_MIN, Importance: 0.9500278100195876
# Feature: 0810_MS_blue_5, Importance: 0.4660827821708422
# Feature: 0810_MS_green_SUM, Importance: 0.5345432348987054
# Feature: 0810_MS_green_MEAN, Importance: 0.3417737084099663
# Feature: 0810_MS_green_MEDIAN, Importance: 0.5849264643758129
# Feature: 0810_MS_green_STDEV, Importance: 0.47674889588173974
# Feature: 0810_MS_green_MIN, Importance: 0.4927622293059672
# Feature: 0810_MS_green_5, Importance: 0.09937222019268949
# Feature: 0810_MS_nir_SUM, Importance: 0.1785745239085752
# Feature: 0810_MS_nir_MEAN, Importance: 0.053164675902096434
# Feature: 0810_MS_nir_MEDIAN, Importance: 0.047518877813341624
# Feature: 0810_MS_nir_STDEV, Importance: 0.5732921601681485
# Feature: 0810_MS_nir_MIN, Importance: 0.5672495824496718
# Feature: 0810_MS_nir_5, Importance: 0.15779232283509587
# Feature: 0810_MS_red_SUM, Importance: 0.021868105461282775
# Feature: 0810_MS_red_MEAN, Importance: 0.2185981778471562
# Feature: 0810_MS_red_MEDIAN, Importance: 0.04329095062428548
# Feature: 0810_MS_red_STDEV, Importance: 0.07110368614798661
# Feature: 0810_MS_red_MIN, Importance: 0.3009855976084318
# Feature: 0810_MS_red_5, Importance: 0.20035734954750964
# Feature: 0810_MS_redge_SUM, Importance: 0.12369090184558125
# Feature: 0810_MS_redge_MEAN, Importance: 0.24035424341754108
# Feature: 0810_MS_redge_MEDIAN, Importance: 0.4183757975110854
# Feature: 0810_MS_redge_STDEV, Importance: 0.11765882943127971
# Feature: 0810_MS_redge_MIN, Importance: 0.46499479706825714
# Feature: 0810_MS_redge_5, Importance: 0.24835245352445526
# Feature: 0816_NC_red_SUM, Importance: 0.2035882960812902
# Feature: 0816_NC_red_MEAN, Importance: 0.2851250784000908
# Feature: 0816_NC_red_MEDIAN, Importance: 0.10326552499851642
# Feature: 0816_NC_red_STDEV, Importance: 0.22477160367408547
# Feature: 0816_NC_red_MIN, Importance: 1.0108839398862028
# Feature: 0816_NC_red_5, Importance: 0.2110661169456795
# Feature: 0816_NC_green_SUM, Importance: 0.06762141905356014
# Feature: 0816_NC_green_MEAN, Importance: 0.006100174380854959
# Feature: 0816_NC_green_MEDIAN, Importance: 0.2392421939743992
# Feature: 0816_NC_green_STDEV, Importance: 0.08093020317438715
# Feature: 0816_NC_green_MIN, Importance: 0.22676484334508687
# Feature: 0816_NC_green_5, Importance: 0.04960412420665104
# Feature: 0816_NC_blue_SUM, Importance: 0.09027634039476308
# Feature: 0816_NC_blue_MEAN, Importance: 0.15856080493112484
# Feature: 0816_NC_blue_MEDIAN, Importance: 0.36705804926167335
# Feature: 0816_NC_blue_STDEV, Importance: 0.5967271102317292
# Feature: 0816_NC_blue_MIN, Importance: 1.0981964096849892
# Feature: 0816_NC_blue_5, Importance: 0.11873570983271768
# Feature: 0816_MS_blue_SUM, Importance: 0.18503663017084182
# Feature: 0816_MS_blue_MEAN, Importance: 0.1515277163643241
# Feature: 0816_MS_blue_MEDIAN, Importance: 0.11898978174020255
# Feature: 0816_MS_blue_STDEV, Importance: 0.1398259437716362
# Feature: 0816_MS_blue_MIN, Importance: 0.39989176233523166
# Feature: 0816_MS_blue_5, Importance: 0.30567682525381357
# Feature: 0816_MS_green_SUM, Importance: 0.08804467035439949
# Feature: 0816_MS_green_MEAN, Importance: 0.15641953117509808
# Feature: 0816_MS_green_MEDIAN, Importance: 0.12604185657931513
# Feature: 0816_MS_green_STDEV, Importance: 0.6476579562845987
# Feature: 0816_MS_green_MIN, Importance: 0.01864908333303371
# Feature: 0816_MS_green_5, Importance: 0.16501774150124113
# Feature: 0816_MS_nir_SUM, Importance: 0.22630914351090325
# Feature: 0816_MS_nir_MEAN, Importance: 0.010610600891854002
# Feature: 0816_MS_nir_MEDIAN, Importance: 0.414342654558022
# Feature: 0816_MS_nir_STDEV, Importance: 0.19490652710420678
# Feature: 0816_MS_nir_MIN, Importance: 0.15600833643877926
# Feature: 0816_MS_nir_5, Importance: 0.05736114975537187
# Feature: 0816_MS_red_SUM, Importance: 0.09759525137148407
# Feature: 0816_MS_red_MEAN, Importance: 0.024943682704790963
# Feature: 0816_MS_red_MEDIAN, Importance: 0.34758276059714727
# Feature: 0816_MS_red_STDEV, Importance: 0.3552911261312868
# Feature: 0816_MS_red_MIN, Importance: 1.292090601245699
# Feature: 0816_MS_red_5, Importance: 0.26762673026644906
# Feature: 0816_MS_redge_SUM, Importance: 0.23680011730544623
# Feature: 0816_MS_redge_MEAN, Importance: 0.21963824775131102
# Feature: 0816_MS_redge_MEDIAN, Importance: 0.12445634984330504
# Feature: 0816_MS_redge_STDEV, Importance: 0.07102606412662593
# Feature: 0816_MS_redge_MIN, Importance: 0.4213256396382471
# Feature: 0816_MS_redge_5, Importance: 0.375252403953076
# Feature: 0826_NC_red_SUM, Importance: 0.1387082047652428
# Feature: 0826_NC_red_MEAN, Importance: 0.05680048696348716
# Feature: 0826_NC_red_MEDIAN, Importance: 0.1664049250055541
# Feature: 0826_NC_red_STDEV, Importance: 0.42635338861282296
# Feature: 0826_NC_red_MIN, Importance: 0.3867252826183953
# Feature: 0826_NC_red_5, Importance: 0.2891092194888448
# Feature: 0826_NC_green_SUM, Importance: 0.17054344277428457
# Feature: 0826_NC_green_MEAN, Importance: 0.10651744137428457
# Feature: 0826_NC_green_MEDIAN, Importance: 0.1397235229023829
# Feature: 0826_NC_green_STDEV, Importance: 0.39272968312483736
# Feature: 0826_NC_green_MIN, Importance: 0.5695856939756704
# Feature: 0826_NC_green_5, Importance: 0.005515164243096976
# Feature: 0826_NC_blue_SUM, Importance: 0.10347306836256906
# Feature: 0826_NC_blue_MEAN, Importance: 0.04929032666269679
# Feature: 0826_NC_blue_MEDIAN, Importance: 0.04571982288739958
# Feature: 0826_NC_blue_STDEV, Importance: 0.3603793222071384
# Feature: 0826_NC_blue_MIN, Importance: 0.4309737391148331
# Feature: 0826_NC_blue_5, Importance: 0.1764261117847871
# Feature: 0826_MS_blue_SUM, Importance: 0.47357144528267686
# Feature: 0826_MS_blue_MEAN, Importance: 0.2810790677249418
# Feature: 0826_MS_blue_MEDIAN, Importance: 0.3698860988588228
# Feature: 0826_MS_blue_STDEV, Importance: 0.6075857700085947
# Feature: 0826_MS_blue_MIN, Importance: 0.2943457835724479
# Feature: 0826_MS_blue_5, Importance: 0.057186068044716105
# Feature: 0826_MS_green_SUM, Importance: 0.46751114741339606
# Feature: 0826_MS_green_MEAN, Importance: 0.19938441036425875
# Feature: 0826_MS_green_MEDIAN, Importance: 0.4920596396475348
# Feature: 0826_MS_green_STDEV, Importance: 0.12687488333465957
# Feature: 0826_MS_green_MIN, Importance: 0.4653406780389687
# Feature: 0826_MS_green_5, Importance: 0.3250742683775212
# Feature: 0826_MS_nir_SUM, Importance: 0.06190374448636794
# Feature: 0826_MS_nir_MEAN, Importance: 0.49492762699657267
# Feature: 0826_MS_nir_MEDIAN, Importance: 0.6895491922589341
# Feature: 0826_MS_nir_STDEV, Importance: 0.29776453023811317
# Feature: 0826_MS_nir_MIN, Importance: 0.6265349343617704
# Feature: 0826_MS_nir_5, Importance: 1.1275057912643118
# Feature: 0826_MS_red_SUM, Importance: 0.044902358044626334
# Feature: 0826_MS_red_MEAN, Importance: 0.2750755094861653
# Feature: 0826_MS_red_MEDIAN, Importance: 0.029062957137396657
# Feature: 0826_MS_red_STDEV, Importance: 0.11962654138516021
# Feature: 0826_MS_red_MIN, Importance: 0.21443947386459772
# Feature: 0826_MS_red_5, Importance: 0.5635286526381463
# Feature: 0826_MS_redge_SUM, Importance: 0.03435270296132504
# Feature: 0826_MS_redge_MEAN, Importance: 0.07684192799678721
# Feature: 0826_MS_redge_MEDIAN, Importance: 0.08293130227145072
# Feature: 0826_MS_redge_STDEV, Importance: 0.43248816364913667
# Feature: 0826_MS_redge_MIN, Importance: 0.4219239918010203
# Feature: 0826_MS_redge_5, Importance: 0.28097949491389385
# Feature: 0830_NC_red_SUM, Importance: 0.08010375605348204
# Feature: 0830_NC_red_MEAN, Importance: 0.02587349653802161
# Feature: 0830_NC_red_MEDIAN, Importance: 0.14971031936762763
# Feature: 0830_NC_red_STDEV, Importance: 0.2261847701907545
# Feature: 0830_NC_red_MIN, Importance: 0.22921512885060621
# Feature: 0830_NC_red_5, Importance: 0.22876117483319405
# Feature: 0830_NC_green_SUM, Importance: 0.2279040169796282
# Feature: 0830_NC_green_MEAN, Importance: 0.16183467250054306
# Feature: 0830_NC_green_MEDIAN, Importance: 0.3908679378948334
# Feature: 0830_NC_green_STDEV, Importance: 0.003197461502431641
# Feature: 0830_NC_green_MIN, Importance: 0.630924819369918
# Feature: 0830_NC_green_5, Importance: 0.39812771242406425
# Feature: 0830_NC_blue_SUM, Importance: 0.1263353055384041
# Feature: 0830_NC_blue_MEAN, Importance: 0.23947199195310426
# Feature: 0830_NC_blue_MEDIAN, Importance: 0.031462431096987625
# Feature: 0830_NC_blue_STDEV, Importance: 0.8398804663180706
# Feature: 0830_NC_blue_MIN, Importance: 0.008916955435521894
# Feature: 0830_NC_blue_5, Importance: 0.008933394727525098
# Feature: 0830_MS_blue_SUM, Importance: 0.11847889564775152
# Feature: 0830_MS_blue_MEAN, Importance: 0.45972596330880333
# Feature: 0830_MS_blue_MEDIAN, Importance: 0.038430717366103505
# Feature: 0830_MS_blue_STDEV, Importance: 0.022915931755937445
# Feature: 0830_MS_blue_MIN, Importance: 0.613903528383248
# Feature: 0830_MS_blue_5, Importance: 0.5243137779881578
# Feature: 0830_MS_green_SUM, Importance: 0.018820821204214713
# Feature: 0830_MS_green_MEAN, Importance: 0.34731469652056907
# Feature: 0830_MS_green_MEDIAN, Importance: 0.19524808042166947
# Feature: 0830_MS_green_STDEV, Importance: 0.40953274933673794
# Feature: 0830_MS_green_MIN, Importance: 0.08597461442914327
# Feature: 0830_MS_green_5, Importance: 0.3173501383724401
# Feature: 0830_MS_nir_SUM, Importance: 0.024217402936826286
# Feature: 0830_MS_nir_MEAN, Importance: 0.08647765014427214
# Feature: 0830_MS_nir_MEDIAN, Importance: 0.10852831763667119
# Feature: 0830_MS_nir_STDEV, Importance: 0.10413590375029387
# Feature: 0830_MS_nir_MIN, Importance: 0.12731637337522617
# Feature: 0830_MS_nir_5, Importance: 0.37279049455165963
# Feature: 0830_MS_red_SUM, Importance: 0.411424081300533
# Feature: 0830_MS_red_MEAN, Importance: 0.022665397784853766
# Feature: 0830_MS_red_MEDIAN, Importance: 0.03843481304817343
# Feature: 0830_MS_red_STDEV, Importance: 0.28601005887675224
# Feature: 0830_MS_red_MIN, Importance: 0.6015133983586611
# Feature: 0830_MS_red_5, Importance: 1.1556624474778832
# Feature: 0830_MS_redge_SUM, Importance: 0.25265955099377846
# Feature: 0830_MS_redge_MEAN, Importance: 0.009084767719108934
# Feature: 0830_MS_redge_MEDIAN, Importance: 0.17304990892533445
# Feature: 0830_MS_redge_STDEV, Importance: 0.04507693405798817
# Feature: 0830_MS_redge_MIN, Importance: 0.20472377826088115
# Feature: 0830_MS_redge_5, Importance: 0.38949188764738235
# Feature: 0910_NC_red_SUM, Importance: 0.33544238293265544
# Feature: 0910_NC_red_MEAN, Importance: 0.1071504232048947
# Feature: 0910_NC_red_MEDIAN, Importance: 0.19604696173161085
# Feature: 0910_NC_red_STDEV, Importance: 0.6791752512650793
# Feature: 0910_NC_red_MIN, Importance: 0.20349262436288146
# Feature: 0910_NC_red_5, Importance: 0.7395681957254102
# Feature: 0910_NC_green_SUM, Importance: 0.32642500682990694
# Feature: 0910_NC_green_MEAN, Importance: 0.12078220787659819
# Feature: 0910_NC_green_MEDIAN, Importance: 0.1590997006455911
# Feature: 0910_NC_green_STDEV, Importance: 0.503924685607446
# Feature: 0910_NC_green_MIN, Importance: 0.17800857000402076
# Feature: 0910_NC_green_5, Importance: 0.15191567299255138
# Feature: 0910_NC_blue_SUM, Importance: 0.10702425811080407
# Feature: 0910_NC_blue_MEAN, Importance: 0.10390997355408083
# Feature: 0910_NC_blue_MEDIAN, Importance: 0.36115040184018454
# Feature: 0910_NC_blue_STDEV, Importance: 0.08156654342396709
# Feature: 0910_NC_blue_MIN, Importance: 0.5000730716109303
# Feature: 0910_NC_blue_5, Importance: 0.35730554253585445
# Feature: 0910_MS_blue_SUM, Importance: 0.3776191381916087
# Feature: 0910_MS_blue_MEAN, Importance: 0.23009930338945506
# Feature: 0910_MS_blue_MEDIAN, Importance: 0.0018111164651435669
# Feature: 0910_MS_blue_STDEV, Importance: 0.178228239593592
# Feature: 0910_MS_blue_MIN, Importance: 0.5025538438702172
# Feature: 0910_MS_blue_5, Importance: 0.011501979432310993
# Feature: 0910_MS_green_SUM, Importance: 0.1640237313597545
# Feature: 0910_MS_green_MEAN, Importance: 0.0908402464934832
# Feature: 0910_MS_green_MEDIAN, Importance: 0.47260727708027156
# Feature: 0910_MS_green_STDEV, Importance: 0.04758656714496754
# Feature: 0910_MS_green_MIN, Importance: 0.7951947748274573
# Feature: 0910_MS_green_5, Importance: 0.40697705021081854
# Feature: 0910_MS_nir_SUM, Importance: 0.5405952954399261
# Feature: 0910_MS_nir_MEAN, Importance: 0.19486597391504845
# Feature: 0910_MS_nir_MEDIAN, Importance: 0.11306975066502699
# Feature: 0910_MS_nir_STDEV, Importance: 0.3205386778023931
# Feature: 0910_MS_nir_MIN, Importance: 0.6973192836165341
# ...
# Feature: 0816_NC_green_MEDIAN, Importance: 1
# Feature: 0816_NC_green_STDEV, Importance: 0
# Feature: 0816_NC_green_MIN, Importance: 2
# Feature: 0816_NC_green_5, Importance: 2
# Feature: 0816_NC_blue_SUM, Importance: 1
# Feature: 0816_NC_blue_MEAN, Importance: 0
# Feature: 0816_NC_blue_MEDIAN, Importance: 1
# Feature: 0816_NC_blue_STDEV, Importance: 9
# Feature: 0816_NC_blue_MIN, Importance: 2
# Feature: 0816_NC_blue_5, Importance: 2
# Feature: 0816_MS_blue_SUM, Importance: 2
# Feature: 0816_MS_blue_MEAN, Importance: 0
# Feature: 0816_MS_blue_MEDIAN, Importance: 1
# Feature: 0816_MS_blue_STDEV, Importance: 1
# Feature: 0816_MS_blue_MIN, Importance: 1
# Feature: 0816_MS_blue_5, Importance: 0
# Feature: 0816_MS_green_SUM, Importance: 0
# Feature: 0816_MS_green_MEAN, Importance: 1
# Feature: 0816_MS_green_MEDIAN, Importance: 3
# Feature: 0816_MS_green_STDEV, Importance: 0
# Feature: 0816_MS_green_MIN, Importance: 5
# Feature: 0816_MS_green_5, Importance: 2
# Feature: 0816_MS_nir_SUM, Importance: 1
# Feature: 0816_MS_nir_MEAN, Importance: 0
# Feature: 0816_MS_nir_MEDIAN, Importance: 3
# Feature: 0816_MS_nir_STDEV, Importance: 2
# Feature: 0816_MS_nir_MIN, Importance: 8
# Feature: 0816_MS_nir_5, Importance: 1
# Feature: 0816_MS_red_SUM, Importance: 0
# Feature: 0816_MS_red_MEAN, Importance: 0
# Feature: 0816_MS_red_MEDIAN, Importance: 1
# Feature: 0816_MS_red_STDEV, Importance: 4
# Feature: 0816_MS_red_MIN, Importance: 29
# Feature: 0816_MS_red_5, Importance: 1
# Feature: 0816_MS_redge_SUM, Importance: 1
# Feature: 0816_MS_redge_MEAN, Importance: 0
# Feature: 0816_MS_redge_MEDIAN, Importance: 2
# Feature: 0816_MS_redge_STDEV, Importance: 4
# Feature: 0816_MS_redge_MIN, Importance: 3
# Feature: 0816_MS_redge_5, Importance: 2
# Feature: 0826_NC_red_SUM, Importance: 0
# Feature: 0826_NC_red_MEAN, Importance: 0
# Feature: 0826_NC_red_MEDIAN, Importance: 1
# Feature: 0826_NC_red_STDEV, Importance: 4
# Feature: 0826_NC_red_MIN, Importance: 7
# Feature: 0826_NC_red_5, Importance: 4
# Feature: 0826_NC_green_SUM, Importance: 2
# Feature: 0826_NC_green_MEAN, Importance: 1
# Feature: 0826_NC_green_MEDIAN, Importance: 2
# Feature: 0826_NC_green_STDEV, Importance: 1
# Feature: 0826_NC_green_MIN, Importance: 1
# Feature: 0826_NC_green_5, Importance: 1
# Feature: 0826_NC_blue_SUM, Importance: 3
# Feature: 0826_NC_blue_MEAN, Importance: 0
# Feature: 0826_NC_blue_MEDIAN, Importance: 1
# Feature: 0826_NC_blue_STDEV, Importance: 4
# Feature: 0826_NC_blue_MIN, Importance: 2
# Feature: 0826_NC_blue_5, Importance: 0
# Feature: 0826_MS_blue_SUM, Importance: 1
# Feature: 0826_MS_blue_MEAN, Importance: 4
# Feature: 0826_MS_blue_MEDIAN, Importance: 1
# Feature: 0826_MS_blue_STDEV, Importance: 3
# Feature: 0826_MS_blue_MIN, Importance: 7
# Feature: 0826_MS_blue_5, Importance: 2
# Feature: 0826_MS_green_SUM, Importance: 1
# Feature: 0826_MS_green_MEAN, Importance: 1
# Feature: 0826_MS_green_MEDIAN, Importance: 3
# Feature: 0826_MS_green_STDEV, Importance: 1
# Feature: 0826_MS_green_MIN, Importance: 8
# Feature: 0826_MS_green_5, Importance: 2
# Feature: 0826_MS_nir_SUM, Importance: 1
# Feature: 0826_MS_nir_MEAN, Importance: 2
# Feature: 0826_MS_nir_MEDIAN, Importance: 1
# Feature: 0826_MS_nir_STDEV, Importance: 5
# Feature: 0826_MS_nir_MIN, Importance: 14
# Feature: 0826_MS_nir_5, Importance: 4
# Feature: 0826_MS_red_SUM, Importance: 3
# Feature: 0826_MS_red_MEAN, Importance: 1
# Feature: 0826_MS_red_MEDIAN, Importance: 4
# Feature: 0826_MS_red_STDEV, Importance: 3
# Feature: 0826_MS_red_MIN, Importance: 4
# Feature: 0826_MS_red_5, Importance: 1
# Feature: 0826_MS_redge_SUM, Importance: 4
# Feature: 0826_MS_redge_MEAN, Importance: 2
# Feature: 0826_MS_redge_MEDIAN, Importance: 3
# Feature: 0826_MS_redge_STDEV, Importance: 1
# Feature: 0826_MS_redge_MIN, Importance: 1
# Feature: 0826_MS_redge_5, Importance: 10
# Feature: 0830_NC_red_SUM, Importance: 1
# Feature: 0830_NC_red_MEAN, Importance: 1
# Feature: 0830_NC_red_MEDIAN, Importance: 0
# Feature: 0830_NC_red_STDEV, Importance: 4
# Feature: 0830_NC_red_MIN, Importance: 4
# Feature: 0830_NC_red_5, Importance: 4
# Feature: 0830_NC_green_SUM, Importance: 2
# Feature: 0830_NC_green_MEAN, Importance: 0
# Feature: 0830_NC_green_MEDIAN, Importance: 0
# Feature: 0830_NC_green_STDEV, Importance: 0
# Feature: 0830_NC_green_MIN, Importance: 6
# Feature: 0830_NC_green_5, Importance: 1
# Feature: 0830_NC_blue_SUM, Importance: 1
# Feature: 0830_NC_blue_MEAN, Importance: 1
# Feature: 0830_NC_blue_MEDIAN, Importance: 0
# Feature: 0830_NC_blue_STDEV, Importance: 1
# Feature: 0830_NC_blue_MIN, Importance: 0
# Feature: 0830_NC_blue_5, Importance: 4
# Feature: 0830_MS_blue_SUM, Importance: 5
# Feature: 0830_MS_blue_MEAN, Importance: 0
# Feature: 0830_MS_blue_MEDIAN, Importance: 3
# Feature: 0830_MS_blue_STDEV, Importance: 3
# Feature: 0830_MS_blue_MIN, Importance: 3
# Feature: 0830_MS_blue_5, Importance: 21
# Feature: 0830_MS_green_SUM, Importance: 4
# Feature: 0830_MS_green_MEAN, Importance: 2
# Feature: 0830_MS_green_MEDIAN, Importance: 3
# Feature: 0830_MS_green_STDEV, Importance: 5
# Feature: 0830_MS_green_MIN, Importance: 4
# Feature: 0830_MS_green_5, Importance: 9
# Feature: 0830_MS_nir_SUM, Importance: 5
# Feature: 0830_MS_nir_MEAN, Importance: 2
# Feature: 0830_MS_nir_MEDIAN, Importance: 2
# Feature: 0830_MS_nir_STDEV, Importance: 3
# Feature: 0830_MS_nir_MIN, Importance: 4
# Feature: 0830_MS_nir_5, Importance: 5
# Feature: 0830_MS_red_SUM, Importance: 1
# Feature: 0830_MS_red_MEAN, Importance: 4
# Feature: 0830_MS_red_MEDIAN, Importance: 0
# Feature: 0830_MS_red_STDEV, Importance: 2
# Feature: 0830_MS_red_MIN, Importance: 4
# Feature: 0830_MS_red_5, Importance: 4
# Feature: 0830_MS_redge_SUM, Importance: 5
# Feature: 0830_MS_redge_MEAN, Importance: 1
# Feature: 0830_MS_redge_MEDIAN, Importance: 0
# Feature: 0830_MS_redge_STDEV, Importance: 4
# Feature: 0830_MS_redge_MIN, Importance: 2
# Feature: 0830_MS_redge_5, Importance: 6
# Feature: 0910_NC_red_SUM, Importance: 1
# Feature: 0910_NC_red_MEAN, Importance: 3
# Feature: 0910_NC_red_MEDIAN, Importance: 3
# Feature: 0910_NC_red_STDEV, Importance: 1
# Feature: 0910_NC_red_MIN, Importance: 4
# Feature: 0910_NC_red_5, Importance: 0
# Feature: 0910_NC_green_SUM, Importance: 1
# Feature: 0910_NC_green_MEAN, Importance: 0
# Feature: 0910_NC_green_MEDIAN, Importance: 0
# Feature: 0910_NC_green_STDEV, Importance: 0
# Feature: 0910_NC_green_MIN, Importance: 1
# Feature: 0910_NC_green_5, Importance: 0
# Feature: 0910_NC_blue_SUM, Importance: 0
# Feature: 0910_NC_blue_MEAN, Importance: 0
# Feature: 0910_NC_blue_MEDIAN, Importance: 2
# Feature: 0910_NC_blue_STDEV, Importance: 4
# Feature: 0910_NC_blue_MIN, Importance: 0
# Feature: 0910_NC_blue_5, Importance: 4
# Feature: 0910_MS_blue_SUM, Importance: 1
# Feature: 0910_MS_blue_MEAN, Importance: 6
# Feature: 0910_MS_blue_MEDIAN, Importance: 3
# Feature: 0910_MS_blue_STDEV, Importance: 0
# Feature: 0910_MS_blue_MIN, Importance: 3
# Feature: 0910_MS_blue_5, Importance: 1
# Feature: 0910_MS_green_SUM, Importance: 1
# Feature: 0910_MS_green_MEAN, Importance: 0
# Feature: 0910_MS_green_MEDIAN, Importance: 1
# Feature: 0910_MS_green_STDEV, Importance: 6
# Feature: 0910_MS_green_MIN, Importance: 4
# Feature: 0910_MS_green_5, Importance: 6
# Feature: 0910_MS_nir_SUM, Importance: 3
# Feature: 0910_MS_nir_MEAN, Importance: 1
# Feature: 0910_MS_nir_MEDIAN, Importance: 2
# Feature: 0910_MS_nir_STDEV, Importance: 6
# Feature: 0910_MS_nir_MIN, Importance: 21
# Feature: 0910_MS_nir_5, Importance: 3
# Feature: 0910_MS_red_SUM, Importance: 3
# Feature: 0910_MS_red_MEAN, Importance: 1
# Feature: 0910_MS_red_MEDIAN, Importance: 1
# Feature: 0910_MS_red_STDEV, Importance: 4
# Feature: 0910_MS_red_MIN, Importance: 2
# Feature: 0910_MS_red_5, Importance: 1
# Feature: 0910_MS_redge_SUM, Importance: 13
# Feature: 0910_MS_redge_MEAN, Importance: 1
# Feature: 0910_MS_redge_MEDIAN, Importance: 1
# Feature: 0910_MS_redge_STDEV, Importance: 4
# Feature: 0910_MS_redge_MIN, Importance: 3
# Feature: 0910_MS_redge_5, Importance: 5
# Feature: 0916_NC_red_SUM, Importance: 3
# Feature: 0916_NC_red_MEAN, Importance: 4
# Feature: 0916_NC_red_MEDIAN, Importance: 2
# Feature: 0916_NC_red_STDEV, Importance: 9
# Feature: 0916_NC_red_MIN, Importance: 2
# Feature: 0916_NC_red_5, Importance: 1
# Feature: 0916_NC_green_SUM, Importance: 3
# Feature: 0916_NC_green_MEAN, Importance: 0
# Feature: 0916_NC_green_MEDIAN, Importance: 2
# Feature: 0916_NC_green_STDEV, Importance: 4
# Feature: 0916_NC_green_MIN, Importance: 0
# Feature: 0916_NC_green_5, Importance: 0
# Feature: 0916_NC_blue_SUM, Importance: 1
# Feature: 0916_NC_blue_MEAN, Importance: 1
# Feature: 0916_NC_blue_MEDIAN, Importance: 2
# Feature: 0916_NC_blue_STDEV, Importance: 2
# Feature: 0916_NC_blue_MIN, Importance: 3
# Feature: 0916_NC_blue_5, Importance: 6
# Feature: 0916_MS_blue_SUM, Importance: 3
# Feature: 0916_MS_blue_MEAN, Importance: 6
# Feature: 0916_MS_blue_MEDIAN, Importance: 1
# Feature: 0916_MS_blue_STDEV, Importance: 1
# Feature: 0916_MS_blue_MIN, Importance: 4
# Feature: 0916_MS_blue_5, Importance: 1
# Feature: 0916_MS_green_SUM, Importance: 1
# Feature: 0916_MS_green_MEAN, Importance: 0
# Feature: 0916_MS_green_MEDIAN, Importance: 1
# Feature: 0916_MS_green_STDEV, Importance: 1
# Feature: 0916_MS_green_MIN, Importance: 3
# Feature: 0916_MS_green_5, Importance: 2
# Feature: 0916_MS_nir_SUM, Importance: 2
# Feature: 0916_MS_nir_MEAN, Importance: 0
# Feature: 0916_MS_nir_MEDIAN, Importance: 0
# Feature: 0916_MS_nir_STDEV, Importance: 3
# Feature: 0916_MS_nir_MIN, Importance: 2
# Feature: 0916_MS_nir_5, Importance: 3
# Feature: 0916_MS_red_SUM, Importance: 2
# Feature: 0916_MS_red_MEAN, Importance: 1
# Feature: 0916_MS_red_MEDIAN, Importance: 2
# Feature: 0916_MS_red_STDEV, Importance: 8
# Feature: 0916_MS_red_MIN, Importance: 0
# Feature: 0916_MS_red_5, Importance: 2
# Feature: 0916_MS_redge_SUM, Importance: 1
# Feature: 0916_MS_redge_MEAN, Importance: 3
# Feature: 0916_MS_redge_MEDIAN, Importance: 4
# Feature: 0916_MS_redge_STDEV, Importance: 6
# Feature: 0916_MS_redge_MIN, Importance: 3
# Feature: 0916_MS_redge_5, Importance: 0
# Feature: 0930_NC_red_SUM, Importance: 1
# Feature: 0930_NC_red_MEAN, Importance: 2
# Feature: 0930_NC_red_MEDIAN, Importance: 3
# Feature: 0930_NC_red_STDEV, Importance: 5
# Feature: 0930_NC_red_MIN, Importance: 0
# Feature: 0930_NC_red_5, Importance: 2
# Feature: 0930_NC_green_SUM, Importance: 2
# Feature: 0930_NC_green_MEAN, Importance: 0
# Feature: 0930_NC_green_MEDIAN, Importance: 2
# Feature: 0930_NC_green_STDEV, Importance: 7
# Feature: 0930_NC_green_MIN, Importance: 1
# Feature: 0930_NC_green_5, Importance: 0
# Feature: 0930_NC_blue_SUM, Importance: 3
# Feature: 0930_NC_blue_MEAN, Importance: 1
# Feature: 0930_NC_blue_MEDIAN, Importance: 1
# Feature: 0930_NC_blue_STDEV, Importance: 5
# Feature: 0930_NC_blue_MIN, Importance: 0
# Feature: 0930_NC_blue_5, Importance: 8
#
#
# *****************************************************************
#
# -------------------------------------
# PLOTTING TOP FEATURES FOR EACH MODEL
# -------------------------------------
#
# --- Generating and saving feature importance figures ---
#
# K-Nearest_Neighbors feature importances file not found.
# Support_Vector_Machine feature importances file not found.
# Gaussian_Naive_Bayes feature importances file not found.
# Multilayer_Perceptron feature importances file not found.
# Quadratic_Discriminant_Analysis feature importances file not found.
#
# ----------------------------------------------
# EACH MODEL's TOP FEATURES HAVE BEEN COMPLETED!
# ----------------------------------------------
#
# *****************************************************************
#
# ---------------------------------------
# GETTING THE TOP PERFORMING MODELS NAME
# ----------------------------------------
# The top model is: Decision Tree
#
# ------------------
# GOT THE TOP MODEL!
# -------------------
#
# Top performing model was:
#  Decision Tree
#
# *****************************************************************
#
# ------------------------------------------
# GETTING THE TOP FEATURES OF THE TOP MODEL!
# -------------------------------------------
#
# --- Loading in the file associated to the top models features for ---
#              Feature  Importance
# 0  0706_NC_blue_MEAN    0.036250
# 1  0615_MS_red_STDEV    0.035579
# 2    0606_NC_green_5    0.031004
# 3      0603_MS_red_5    0.029555
# 4  0802_MS_green_MIN    0.028805
#
# -----------------------
# TOP FEATURES LOADED IN!
# ------------------------
#
# *****************************************************************
#
# ------------------------------------------
# GENERATING NEW INPUT FILE!
# -------------------------------------------
#
# Feature importance dataframe shape: (834, 2)
#
# Top 20 Features:
#
# 0706_NC_blue_MEAN
# 0615_MS_red_STDEV
# 0606_NC_green_5
# 0603_MS_red_5
# 0802_MS_green_MIN
# 0930_NC_red_5
# 0714_MS_redge_STDEV
# 0615_MS_redge_MEAN
# 0826_NC_green_STDEV
# 0726_MS_blue_MEAN
# 0611_MS_nir_5
# 0930_NC_blue_STDEV
# 0628_MS_red_MEAN
# 0603_MS_nir_MEDIAN
# 0615_NC_red_SUM
# 0810_MS_green_5
# 0810_NC_red_STDEV
# 0910_MS_nir_MIN
# 0916_NC_green_MEAN
# 0810_MS_nir_MIN
#
# Length of top features list is: 20
#
# Original Input dataframe features shape: (761, 834)
# New dataframe after feature selections shape: (761, 20)
#
# --------------------------
# NEW INPUT FILE GENERATED!
# --------------------------
#
# *****************************************************************
#
# --------------------------------------------
# SPLITTING DATA INTO TRAINING AND TEST SETS
# --------------------------------------------
# X_train shape: (608, 20)
# y_train shape: (608,)
# X_test shape: (153, 20)
# y_test shape: (153,)
#
# ----------------------------
# DATA SUCCESSFULLY SPLIT!
# ----------------------------
#
# *****************************************************************
#
# -------------------------------------------------------------
# RERUN MODEL USING ONLY TOP MODEL ON TOP FEATURE DATASET
# -------------------------------------------------------------
#
# --- Generating results using feature-selected data ---
#
# --- Saving new model results after feature selection ---
#
# --- Re-Generating feature importance scores for top model ---
#
# ---------------------------------------------------------------
# NEW MODEL RESULTS AND TOP FEATURES MADE WITH NEW FEATURE-DATASET!
# ---------------------------------------------------------------
#
# Results df:
#                           Decision Tree
# Accuracy                      0.575163
# Confusion Matrix  [[59, 36], [29, 29]]
# F1-score                      0.579127
# Precision                     0.585426
# Recall                        0.575163
#
# Feature Importances:
#
# Model: Decision Tree
# Feature: 0706_NC_blue_MEAN, Importance: 0.06824476661797603
# Feature: 0615_MS_red_STDEV, Importance: 0.04046711817631411
# Feature: 0606_NC_green_5, Importance: 0.036711096306882796
# Feature: 0603_MS_red_5, Importance: 0.0657202494720832
# Feature: 0802_MS_green_MIN, Importance: 0.07439629657758096
# Feature: 0930_NC_red_5, Importance: 0.03556692631133124
# Feature: 0714_MS_redge_STDEV, Importance: 0.06219598201652868
# Feature: 0615_MS_redge_MEAN, Importance: 0.04096802280721918
# Feature: 0826_NC_green_STDEV, Importance: 0.08171607692365312
# Feature: 0726_MS_blue_MEAN, Importance: 0.04583538259243838
# Feature: 0611_MS_nir_5, Importance: 0.05015103683109421
# Feature: 0930_NC_blue_STDEV, Importance: 0.06574038202408133
# Feature: 0628_MS_red_MEAN, Importance: 0.03820644620405301
# Feature: 0603_MS_nir_MEDIAN, Importance: 0.08569592063567823
# Feature: 0615_NC_red_SUM, Importance: 0.04206439467238399
# Feature: 0810_MS_green_5, Importance: 0.04140329804766486
# Feature: 0810_NC_red_STDEV, Importance: 0.03983336309114141
# Feature: 0910_MS_nir_MIN, Importance: 0.035464942215451704
# Feature: 0916_NC_green_MEAN, Importance: 0.03608134300291198
# Feature: 0810_MS_nir_MIN, Importance: 0.013536955473531745
#
#
# *****************************************************************
#
# ------------------------------------------------------------
# PLOTTING TOP FEATURES FOR TOP MODEL AFTER FEATURE SELECTION
# ------------------------------------------------------------
#
# --- ReGenerating and saving feature importance figures ---
#
# --------------------------------------------
# TOP MODEL USING TOP FEAUTURES FIGURES MADE!
# --------------------------------------------
#
# ********************************************************************
#
# -----------------------------------------------------------
# CONGRATULATIONS! YOU HAVE RAN THE PIPELINE SUCESSFULLY! :)
# -----------------------------------------------------------

# %% [markdown]
# # CONGRATS YOU RAN THE PIPELINE!

# %% [markdown]
# ### Additional information
#
# #### Unit testing
#
# #### CURRENTLY NOT AVAILBLE IN PUBLIC DIRECTORY
# ##### BUT IF YOU WOULD LIKE TO SEE THE UNIT TESTS PLEASE CONTACT OWNER
# Unit testing is a way to check that you code is doing what you actually want it to do. For example $1 + 1$ does actually $=2$
#
# So, each `.py` file used in the pipeline above had a unit test associated with it seen with a prefix `test_` *filename*`.py`

# %%
# run a unittest on the multicolormaize.py file
# !python ../multicolormaize/test_multicolormaize.py
# Out:
# python: can't open file 'C:\\Users\\amsch\\Documents\\multicolormaize\\multicolormaize\\test_multicolormaize.py': [Errno 2] No such file or directory
